# %% [markdown]
# Problem Statement
# Develop a predictive model with at least 80% accuracy to determine the likelihood of a song entering the top 5 of a specific country's music charts within six months. This model will be based on a dataset comprising music-specific and country-specific features, utilizing machine learning algorithms and feature engineering techniques.

# %%
#Importing necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# Importing the song specific data from our raw_data folder:

# %%
songs_data = pd.read_csv('../raw_data/universal_top_spotify_songs.csv')

# %%
songs_data.head()
# Out:
#                spotify_id                             name  \
# 0  2OzhQlSqBEmt7hmkYxfT6m    Fortnight (feat. Post Malone)
# 1  2GxrNKugF82CnoRFbQfzPf       i like the way you kiss me
# 2  2qSkIjg1o9h3YT9RAgYN75                         Espresso
# 3  6XjDF6nds4DE2BBbagZol6                        Gata Only
# 4  4q5YezDOIPcoLr8R81x9qy  I Can Do It With a Broken Heart
#
#                      artists  daily_rank  daily_movement  weekly_movement  \
# 0  Taylor Swift, Post Malone           1              49               49
# 1                    Artemas           2              48               -1
# 2          Sabrina Carpenter           3              47                4
# 3        FloyyMenor, Cris Mj           4              46               -1
# 4               Taylor Swift           5              45               45
#
#   country snapshot_date  popularity  is_explicit  ...  key loudness mode  \
# 0     NaN    2024-04-25          90        False  ...   11  -10.895    1
# 1     NaN    2024-04-25         100        False  ...   11   -4.263    1
# 2     NaN    2024-04-25          92         True  ...    0   -5.486    1
# 3     NaN    2024-04-25          98         True  ...    8   -8.472    0
# 4     NaN    2024-04-25          84         True  ...    0   -8.290    1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0245      0.499000          0.000006    0.0939    0.319   95.988
# 1       0.0447      0.000938          0.010600    0.0826    0.747  151.647
# 2       0.0293      0.133000          0.000012    0.1970    0.661  103.982
# 3       0.0509      0.446000          0.000024    0.0899    0.669   99.986
# 4       0.0513      0.147000          0.000000    0.1370    0.226  130.018
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 25 columns]

# %%
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683103 entries, 0 to 683102
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   spotify_id          683103 non-null  object
#  1   name                683078 non-null  object
#  2   artists             683078 non-null  object
#  3   daily_rank          683103 non-null  int64
#  4   daily_movement      683103 non-null  int64
#  5   weekly_movement     683103 non-null  int64
#  6   country             673896 non-null  object
#  7   snapshot_date       683103 non-null  object
#  8   popularity          683103 non-null  int64
#  9   is_explicit         683103 non-null  bool
#  10  duration_ms         683103 non-null  int64
#  11  album_name          682853 non-null  object
#  12  album_release_date  682853 non-null  object
#  13  danceability        683103 non-null  float64
#  14  energy              683103 non-null  float64
#  15  key                 683103 non-null  int64
#  16  loudness            683103 non-null  float64
#  17  mode                683103 non-null  int64
#  18  speechiness         683103 non-null  float64
#  19  acousticness        683103 non-null  float64
#  20  instrumentalness    683103 non-null  float64
#  21  liveness            683103 non-null  float64
#  22  valence             683103 non-null  float64
#  23  tempo               683103 non-null  float64
#  24  time_signature      683103 non-null  int64
# dtypes: bool(1), float64(9), int64(8), object(7)
# memory usage: 125.7+ MB

# %% [markdown]
# The first step will be calculating the rate of missing values by Col

# %%
missing = pd.concat([songs_data.isnull().sum(), 100 * songs_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending = False)
# Out:
#                     count         %
# country              9207  1.347820
# album_release_date    250  0.036598
# album_name            250  0.036598
# artists                25  0.003660
# name                   25  0.003660
# key                     0  0.000000
# tempo                   0  0.000000
# valence                 0  0.000000
# liveness                0  0.000000
# instrumentalness        0  0.000000
# acousticness            0  0.000000
# speechiness             0  0.000000
# mode                    0  0.000000
# loudness                0  0.000000
# spotify_id              0  0.000000
# energy                  0  0.000000
# danceability            0  0.000000
# duration_ms             0  0.000000
# is_explicit             0  0.000000
# popularity              0  0.000000
# snapshot_date           0  0.000000
# weekly_movement         0  0.000000
# daily_movement          0  0.000000
# daily_rank              0  0.000000
# time_signature          0  0.000000

# %% [markdown]
# As we can see, country, album_relase_date, album_name, artist and name are the only columns with missing data. We will address these later in our analysis but first lets take a look at the values of categorical features:

# %%
# we will print the top values for the categorical variables in our dataset:
for var in songs_data.select_dtypes(include='object').columns:
    print("Column: " + var)
    print(songs_data[var].value_counts().head())
    print("\n")
# Out:
# Column: spotify_id
# spotify_id
# 3rUGC1vUpkDG9CZFHMur1t    7367
# 5mjYQaktjmjcMKcUIcqz4s    4626
# 1BxfuPKGuaTgP7aM0Bbdwr    4531
# 59NraMJsLaMCVtwXTSia8i    3879
# 56y1jOTK0XSvJzVv9vHQBK    3769
# Name: count, dtype: int64
#
#
# Column: name
# name
# greedy                                            7367
# Strangers                                         4764
# Cruel Summer                                      4531
# One Of The Girls (with JENNIE, Lily Rose Depp)    3938
# Prada                                             3879
# Name: count, dtype: int64
#
#
# Column: artists
# artists
# Taylor Swift     12361
# Tate McRae        8377
# Bad Bunny         6846
# Ariana Grande     6271
# KAROL G           6194
# Name: count, dtype: int64
#
#
# Column: country
# country
# DO    9475
# IT    9474
# NI    9470
# UA    9464
# PL    9464
# Name: count, dtype: int64
#
#
# Column: snapshot_date
# snapshot_date
# 2024-03-16    3942
# 2023-11-20    3866
# 2024-03-18    3836
# 2024-03-14    3769
# 2023-10-27    3766
# Name: count, dtype: int64
#
#
# Column: album_name
# album_name
# nadie sabe lo que va a pasar mañana    14374
# greedy                                  7367
# MAÑANA SERÁ BONITO (BICHOTA SEASON)     6632
# GOLDEN                                  6560
# El Comienzo                             6491
# Name: count, dtype: int64
#
#
# Column: album_release_date
# album_release_date
# 2023-10-13    20457
# 2023-09-15    16265
# 2023-08-25    14325
# 2023-12-01    12670
# 2023-07-28    11237
# Name: count, dtype: int64

# %% [markdown]
# From the analysis of the variables we can infer a couple of things:<br>
#     - need to convert column "snapshot_date" and "album_release_date" to dates<br>
#     - Same song can be repeated multiple times in the dataset<br>
#     - Need more information about the Country data (something seems to be wrong as the same count is repeated multiple times) <br><br>
# The first thing we will do is converting to dates:

# %%
songs_data['snapshot_date'] = pd.to_datetime(songs_data['snapshot_date'])
songs_data['album_release_date'] = pd.to_datetime(songs_data['album_release_date'])
#confirm the new data types for the right columns:
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683103 entries, 0 to 683102
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   spotify_id          683103 non-null  object
#  1   name                683078 non-null  object
#  2   artists             683078 non-null  object
#  3   daily_rank          683103 non-null  int64
#  4   daily_movement      683103 non-null  int64
#  5   weekly_movement     683103 non-null  int64
#  6   country             673896 non-null  object
#  7   snapshot_date       683103 non-null  datetime64[ns]
#  8   popularity          683103 non-null  int64
#  9   is_explicit         683103 non-null  bool
#  10  duration_ms         683103 non-null  int64
#  11  album_name          682853 non-null  object
#  12  album_release_date  682853 non-null  datetime64[ns]
#  13  danceability        683103 non-null  float64
#  14  energy              683103 non-null  float64
#  15  key                 683103 non-null  int64
#  16  loudness            683103 non-null  float64
#  17  mode                683103 non-null  int64
#  18  speechiness         683103 non-null  float64
#  19  acousticness        683103 non-null  float64
#  20  instrumentalness    683103 non-null  float64
#  21  liveness            683103 non-null  float64
#  22  valence             683103 non-null  float64
#  23  tempo               683103 non-null  float64
#  24  time_signature      683103 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(9), int64(8), object(5)
# memory usage: 125.7+ MB

# %%
songs_data['snapshot_date'].describe()
# Out:
# count                           683103
# mean     2024-01-19 14:16:32.533190400
# min                2023-10-18 00:00:00
# 25%                2023-12-03 00:00:00
# 50%                2024-01-19 00:00:00
# 75%                2024-03-06 00:00:00
# max                2024-04-25 00:00:00
# Name: snapshot_date, dtype: object

# %% [markdown]
# Before we tackle the full analysis of the data, we want to confirm the snapshot date covers the right amount of dates. from the previous analysis we can see that we are looking at song info from mid Oct 2023 to end of Apr 2024 (almost 6 months). <br><br>
# Now that we have identified this, lets analyze the values for 'spotify_id'

# %%
songs_data[(songs_data['name'] == 'Fortnight (feat. Post Malone)')]['spotify_id'].value_counts()
# Out:
# spotify_id
# 2OzhQlSqBEmt7hmkYxfT6m    239
# Name: count, dtype: int64

# %% [markdown]
# It looks like the spotify_id is unique for each song so we will use it going forward to identify each song

# %%
songs_data[(songs_data['spotify_id'] == '2OzhQlSqBEmt7hmkYxfT6m') & (songs_data['snapshot_date'] == '2024-04-25')]
# Out:
#                   spotify_id                           name  \
# 0     2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 58    2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 101   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 163   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 220   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 250   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 351   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 466   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 516   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 560   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 600   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 655   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 702   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 772   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 824   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 851   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 920   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 991   2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1001  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1088  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1112  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1150  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1209  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1259  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1321  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1400  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1483  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1553  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1608  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1655  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1758  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1883  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 1904  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2026  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2052  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2116  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2168  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2216  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2250  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2401  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2481  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2516  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2573  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2652  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2736  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2802  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2853  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2908  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 2970  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3104  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3150  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3268  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3366  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3402  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3450  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3501  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3572  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
# 3600  2OzhQlSqBEmt7hmkYxfT6m  Fortnight (feat. Post Malone)
#
#                         artists  daily_rank  daily_movement  weekly_movement  \
# 0     Taylor Swift, Post Malone           1              49               49
# 58    Taylor Swift, Post Malone           9              41               41
# 101   Taylor Swift, Post Malone           2               0               48
# 163   Taylor Swift, Post Malone          14              36               36
# 220   Taylor Swift, Post Malone          21               1               29
# 250   Taylor Swift, Post Malone           1              49               49
# 351   Taylor Swift, Post Malone           2               0               48
# 466   Taylor Swift, Post Malone          17               1               33
# 516   Taylor Swift, Post Malone          17               0               33
# 560   Taylor Swift, Post Malone          11               2               39
# 600   Taylor Swift, Post Malone           1               0               49
# 655   Taylor Swift, Post Malone           6               0               44
# 702   Taylor Swift, Post Malone           3              47               47
# 772   Taylor Swift, Post Malone          23              -2               27
# 824   Taylor Swift, Post Malone          25               4               25
# 851   Taylor Swift, Post Malone           2               0               48
# 920   Taylor Swift, Post Malone          21               3               29
# 991   Taylor Swift, Post Malone          42              -3                8
# 1001  Taylor Swift, Post Malone           2               2               48
# 1088  Taylor Swift, Post Malone          39               3               11
# 1112  Taylor Swift, Post Malone          13               0               37
# 1150  Taylor Swift, Post Malone           1              49               49
# 1209  Taylor Swift, Post Malone          10              40               40
# 1259  Taylor Swift, Post Malone          10              40               40
# 1321  Taylor Swift, Post Malone          22               3               28
# 1400  Taylor Swift, Post Malone           1               2               49
# 1483  Taylor Swift, Post Malone          34              -1               16
# 1553  Taylor Swift, Post Malone           4              46               46
# 1608  Taylor Swift, Post Malone           9              41               41
# 1655  Taylor Swift, Post Malone           6              44               44
# 1758  Taylor Swift, Post Malone           9               1               41
# 1883  Taylor Swift, Post Malone          34              -2               16
# 1904  Taylor Swift, Post Malone           5              45               45
# 2026  Taylor Swift, Post Malone          27               0               23
# 2052  Taylor Swift, Post Malone           3              47               47
# 2116  Taylor Swift, Post Malone          17              13               33
# 2168  Taylor Swift, Post Malone          19               2               31
# 2216  Taylor Swift, Post Malone          17               1               33
# 2250  Taylor Swift, Post Malone           1               0               49
# 2401  Taylor Swift, Post Malone           2              48               48
# 2481  Taylor Swift, Post Malone          32               3               18
# 2516  Taylor Swift, Post Malone          17               1               33
# 2573  Taylor Swift, Post Malone          24               2               26
# 2652  Taylor Swift, Post Malone           3               0               47
# 2736  Taylor Swift, Post Malone          37              13               13
# 2802  Taylor Swift, Post Malone           3              47               47
# 2853  Taylor Swift, Post Malone           4               0               46
# 2908  Taylor Swift, Post Malone           9               3               41
# 2970  Taylor Swift, Post Malone          21               1               29
# 3104  Taylor Swift, Post Malone           5              45               45
# 3150  Taylor Swift, Post Malone           1              49               49
# 3268  Taylor Swift, Post Malone          19               0               31
# 3366  Taylor Swift, Post Malone          17              33               33
# 3402  Taylor Swift, Post Malone           3               2               47
# 3450  Taylor Swift, Post Malone           1              49               49
# 3501  Taylor Swift, Post Malone           2               1               48
# 3572  Taylor Swift, Post Malone          23               3               27
# 3600  Taylor Swift, Post Malone           1              49               49
#
#      country snapshot_date  popularity  is_explicit  ...  key loudness mode  \
# 0        NaN    2024-04-25          90        False  ...   11  -10.895    1
# 58        ZA    2024-04-25          90        False  ...   11  -10.895    1
# 101       VN    2024-04-25          90        False  ...   11  -10.895    1
# 163       VE    2024-04-25          90        False  ...   11  -10.895    1
# 220       UY    2024-04-25          90        False  ...   11  -10.895    1
# 250       US    2024-04-25          90        False  ...   11  -10.895    1
# 351       TW    2024-04-25          90        False  ...   11  -10.895    1
# 466       TH    2024-04-25          90        False  ...   11  -10.895    1
# 516       SV    2024-04-25          90        False  ...   11  -10.895    1
# 560       SK    2024-04-25          90        False  ...   11  -10.895    1
# 600       SG    2024-04-25          90        False  ...   11  -10.895    1
# 655       SE    2024-04-25          90        False  ...   11  -10.895    1
# 702       SA    2024-04-25          90        False  ...   11  -10.895    1
# 772       RO    2024-04-25          90        False  ...   11  -10.895    1
# 824       PY    2024-04-25          90        False  ...   11  -10.895    1
# 851       PT    2024-04-25          90        False  ...   11  -10.895    1
# 920       PL    2024-04-25          90        False  ...   11  -10.895    1
# 991       PK    2024-04-25          90        False  ...   11  -10.895    1
# 1001      PH    2024-04-25          90        False  ...   11  -10.895    1
# 1088      PE    2024-04-25          90        False  ...   11  -10.895    1
# 1112      PA    2024-04-25          90        False  ...   11  -10.895    1
# 1150      NZ    2024-04-25          90        False  ...   11  -10.895    1
# 1209      NO    2024-04-25          90        False  ...   11  -10.895    1
# 1259      NL    2024-04-25          90        False  ...   11  -10.895    1
# 1321      NI    2024-04-25          90        False  ...   11  -10.895    1
# 1400      MY    2024-04-25          90        False  ...   11  -10.895    1
# 1483      MX    2024-04-25          90        False  ...   11  -10.895    1
# 1553      LV    2024-04-25          90        False  ...   11  -10.895    1
# 1608      LU    2024-04-25          90        False  ...   11  -10.895    1
# 1655      LT    2024-04-25          90        False  ...   11  -10.895    1
# 1758      KR    2024-04-25          90        False  ...   11  -10.895    1
# 1883      IT    2024-04-25          90        False  ...   11  -10.895    1
# 1904      IS    2024-04-25          90        False  ...   11  -10.895    1
# 2026      IL    2024-04-25          90        False  ...   11  -10.895    1
# 2052      IE    2024-04-25          90        False  ...   11  -10.895    1
# 2116      ID    2024-04-25          90        False  ...   11  -10.895    1
# 2168      HU    2024-04-25          90        False  ...   11  -10.895    1
# 2216      HN    2024-04-25          90        False  ...   11  -10.895    1
# 2250      HK    2024-04-25          90        False  ...   11  -10.895    1
# 2401      GB    2024-04-25          90        False  ...   11  -10.895    1
# 2481      FR    2024-04-25          90        False  ...   11  -10.895    1
# 2516      FI    2024-04-25          90        False  ...   11  -10.895    1
# 2573      ES    2024-04-25          90        False  ...   11  -10.895    1
# 2652      EE    2024-04-25          90        False  ...   11  -10.895    1
# 2736      EC    2024-04-25          90        False  ...   11  -10.895    1
# 2802      DK    2024-04-25          90        False  ...   11  -10.895    1
# 2853      DE    2024-04-25          90        False  ...   11  -10.895    1
# 2908      CZ    2024-04-25          90        False  ...   11  -10.895    1
# 2970      CR    2024-04-25          90        False  ...   11  -10.895    1
# 3104      CH    2024-04-25          90        False  ...   11  -10.895    1
# 3150      CA    2024-04-25          90        False  ...   11  -10.895    1
# 3268      BR    2024-04-25          90        False  ...   11  -10.895    1
# 3366      BG    2024-04-25          90        False  ...   11  -10.895    1
# 3402      BE    2024-04-25          90        False  ...   11  -10.895    1
# 3450      AU    2024-04-25          90        False  ...   11  -10.895    1
# 3501      AT    2024-04-25          90        False  ...   11  -10.895    1
# 3572      AR    2024-04-25          90        False  ...   11  -10.895    1
# 3600      AE    2024-04-25          90        False  ...   11  -10.895    1
#
#       speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 0          0.0245         0.499          0.000006    0.0939    0.319  95.988
# 58         0.0245         0.499          0.000006    0.0939    0.319  95.988
# 101        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 163        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 220        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 250        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 351        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 466        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 516        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 560        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 600        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 655        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 702        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 772        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 824        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 851        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 920        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 991        0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1001       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1088       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1112       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1150       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1209       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1259       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1321       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1400       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1483       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1553       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1608       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1655       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1758       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1883       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 1904       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2026       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2052       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2116       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2168       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2216       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2250       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2401       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2481       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2516       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2573       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2652       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2736       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2802       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2853       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2908       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 2970       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3104       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3150       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3268       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3366       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3402       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3450       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3501       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3572       0.0245         0.499          0.000006    0.0939    0.319  95.988
# 3600       0.0245         0.499          0.000006    0.0939    0.319  95.988
#
#       time_signature
# 0                  4
# 58                 4
# 101                4
# 163                4
# 220                4
# 250                4
# 351                4
# 466                4
# 516                4
# 560                4
# 600                4
# 655                4
# 702                4
# 772                4
# 824                4
# 851                4
# 920                4
# 991                4
# 1001               4
# 1088               4
# 1112               4
# 1150               4
# 1209               4
# 1259               4
# 1321               4
# 1400               4
# 1483               4
# 1553               4
# 1608               4
# 1655               4
# 1758               4
# 1883               4
# 1904               4
# 2026               4
# 2052               4
# 2116               4
# 2168               4
# 2216               4
# 2250               4
# 2401               4
# 2481               4
# 2516               4
# 2573               4
# 2652               4
# 2736               4
# 2802               4
# 2853               4
# 2908               4
# 2970               4
# 3104               4
# 3150               4
# 3268               4
# 3366               4
# 3402               4
# 3450               4
# 3501               4
# 3572               4
# 3600               4
#
# [58 rows x 25 columns]

# %% [markdown]
# The fact that there are seveal records per song on the same snapshot date implies that each record has a unique Country. so lets try revieweing it by country:

# %%
songs_data[(songs_data['spotify_id'] == '2OzhQlSqBEmt7hmkYxfT6m') & (songs_data['snapshot_date'] == '2024-04-25')]['country'].value_counts().head()
# Out:
# country
# ZA    1
# KR    1
# IS    1
# IL    1
# IE    1
# Name: count, dtype: int64

# %% [markdown]
# <font color="#F22211"> It looks like each record represents a song in a country on a specific day! </font> for each song on each day we have valuable information like artist and album, the ranking in the country as well as changes daily and weekly and several song specific features. It also looks like we only have 9810 songs (definetly not the entirety of songs

# %%
len(songs_data['spotify_id'].unique())
# Out:
# 9810

# %%
songs_data[(songs_data['spotify_id'] == '2OzhQlSqBEmt7hmkYxfT6m') & (songs_data['snapshot_date'] == '2024-04-25')].describe().T
# Out:
#                    count                 mean                  min  \
# daily_rank          58.0                 12.5                  1.0
# daily_movement      58.0            16.431034                 -3.0
# weekly_movement     58.0                 37.5                  8.0
# snapshot_date         58  2024-04-25 00:00:00  2024-04-25 00:00:00
# popularity          58.0                 90.0                 90.0
# duration_ms         58.0             228965.0             228965.0
# album_release_date    58  2024-04-18 00:00:00  2024-04-18 00:00:00
# danceability        58.0                0.675                0.675
# energy              58.0                0.397                0.397
# key                 58.0                 11.0                 11.0
# loudness            58.0              -10.895              -10.895
# mode                58.0                  1.0                  1.0
# speechiness         58.0               0.0245               0.0245
# acousticness        58.0                0.499                0.499
# instrumentalness    58.0             0.000006             0.000006
# liveness            58.0               0.0939               0.0939
# valence             58.0                0.319                0.319
# tempo               58.0               95.988               95.988
# time_signature      58.0                  4.0                  4.0
#
#                                     25%                  50%  \
# daily_rank                         2.25                  9.0
# daily_movement                      0.0                  2.5
# weekly_movement                    29.5                 41.0
# snapshot_date       2024-04-25 00:00:00  2024-04-25 00:00:00
# popularity                         90.0                 90.0
# duration_ms                    228965.0             228965.0
# album_release_date  2024-04-18 00:00:00  2024-04-18 00:00:00
# danceability                      0.675                0.675
# energy                            0.397                0.397
# key                                11.0                 11.0
# loudness                        -10.895              -10.895
# mode                                1.0                  1.0
# speechiness                      0.0245               0.0245
# acousticness                      0.499                0.499
# instrumentalness               0.000006             0.000006
# liveness                         0.0939               0.0939
# valence                           0.319                0.319
# tempo                            95.988               95.988
# time_signature                      4.0                  4.0
#
#                                     75%                  max        std
# daily_rank                         20.5                 42.0   11.40983
# daily_movement                     41.0                 49.0  21.019717
# weekly_movement                   47.75                 49.0   11.40983
# snapshot_date       2024-04-25 00:00:00  2024-04-25 00:00:00        NaN
# popularity                         90.0                 90.0        0.0
# duration_ms                    228965.0             228965.0        0.0
# album_release_date  2024-04-18 00:00:00  2024-04-18 00:00:00        NaN
# danceability                      0.675                0.675        0.0
# energy                            0.397                0.397        0.0
# key                                11.0                 11.0        0.0
# loudness                        -10.895              -10.895        0.0
# mode                                1.0                  1.0        0.0
# speechiness                      0.0245               0.0245        0.0
# acousticness                      0.499                0.499        0.0
# instrumentalness               0.000006             0.000006        0.0
# liveness                         0.0939               0.0939        0.0
# valence                           0.319                0.319        0.0
# tempo                            95.988               95.988        0.0
# time_signature                      4.0                  4.0        0.0

# %% [markdown]
# Once we isolate for a song/snapshot_date we can see the ranks and movements have a more normal behaviour. We also notice that popularity remains constant for the song/snapshotdate (which would indicate popularity worldwide) and all other features of the song remain constant across teh same song/snapshot_date <br>
# Next, lets create the column we want to predict, wether the song is or not in the top 5:

# %%
songs_data['top_5'] = songs_data['daily_rank'] <=5

# %% [markdown]
# Now, we want to start making decisions about the missing values, starting with the country field:

# %%
songs_data[songs_data['country'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9207 entries, 0 to 679511
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   spotify_id          9207 non-null   object
#  1   name                9207 non-null   object
#  2   artists             9207 non-null   object
#  3   daily_rank          9207 non-null   int64
#  4   daily_movement      9207 non-null   int64
#  5   weekly_movement     9207 non-null   int64
#  6   country             0 non-null      object
#  7   snapshot_date       9207 non-null   datetime64[ns]
#  8   popularity          9207 non-null   int64
#  9   is_explicit         9207 non-null   bool
#  10  duration_ms         9207 non-null   int64
#  11  album_name          9204 non-null   object
#  12  album_release_date  9204 non-null   datetime64[ns]
#  13  danceability        9207 non-null   float64
#  14  energy              9207 non-null   float64
#  15  key                 9207 non-null   int64
#  16  loudness            9207 non-null   float64
#  17  mode                9207 non-null   int64
#  18  speechiness         9207 non-null   float64
#  19  acousticness        9207 non-null   float64
#  20  instrumentalness    9207 non-null   float64
#  21  liveness            9207 non-null   float64
#  22  valence             9207 non-null   float64
#  23  tempo               9207 non-null   float64
#  24  time_signature      9207 non-null   int64
#  25  top_5               9207 non-null   bool
# dtypes: bool(2), datetime64[ns](2), float64(9), int64(8), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# It looks like the Nan country is a complete set of information (with no missing data). if we filter it out by a single date:

# %%
songs_data[(songs_data['country'].isnull()) & (songs_data['snapshot_date'] == '2024-04-25')]['spotify_id'].value_counts().head()
# Out:
# spotify_id
# 2OzhQlSqBEmt7hmkYxfT6m    1
# 62E2nR0od0M5HYxuYLaDz7    1
# 5bi0gh89wRuH2OgjdAKFsb    1
# 2h3MDMf8sd9s4XIzpTBIjX    1
# 3eh51r6rFWAlGQRlHx9QnQ    1
# Name: count, dtype: int64

# %% [markdown]
# Our intuition was correct. the missing values of country are for world wide data. we can replace the values with this

# %%
songs_data.loc[songs_data['country'].isnull(), 'country'] = 'Global'

# %% [markdown]
# the next step of our analysis will take us to look at the distributions of the data we have. to do this we will use histograms for the data we have available:

# %%
songs_data.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# Popularity seems to be the only distribution with a weird occurance of numbers around 0 so lets dig into this:

# %%
songs_data.loc[songs_data['popularity']<20, 'name'].value_counts()
# Out:
# name
# yes, and?                         96
# Style (Taylor's Version)          61
# Fortnight (feat. Post Malone)     58
# Blank Space (Taylor's Version)    55
# The Tortured Poets Department     53
#                                   ..
# Ikaria                             1
# Tvoje ruže                         1
# Hoping For Life                    1
# Untangled                          1
# Birta                              1
# Name: count, Length: 1963, dtype: int64

# %%
songs_data[songs_data['name'] == 'yes, and?'].plot.scatter(x = 'snapshot_date', y='popularity')
plt.show()

# %%
songs_data[songs_data['name'] == 'Espresso'].plot.scatter(x = 'snapshot_date', y='popularity')
plt.show()

# %% [markdown]
# When we look at the song with the most number of times ocurrance < 20 and compare this to a "normal" song from our set, we can see that the song "yes, and?" seems to have launched twice thus having a popularity of 0 more than once. To confirm this, lets look at the album release date:

# %%
songs_data.loc[(songs_data['name'] == 'yes, and?') & (songs_data['country'] == 'US'), ['snapshot_date','album_release_date']].sort_values('snapshot_date')
# Out:
#        snapshot_date album_release_date
# 359028    2024-01-14         2024-01-12
# 355378    2024-01-15         2024-01-12
# 351737    2024-01-16         2024-01-12
# 348087    2024-01-17         2024-01-12
# 344437    2024-01-18         2024-01-12
# 340796    2024-01-19         2024-01-12
# 337149    2024-01-20         2024-01-12
# 333500    2024-01-21         2024-01-12
# 329850    2024-01-22         2024-01-12
# 326212    2024-01-23         2024-01-12
# 322563    2024-01-24         2024-01-12
# 318913    2024-01-25         2024-01-12
# 315263    2024-01-26         2024-01-12
# 311615    2024-01-27         2024-01-12
# 307967    2024-01-28         2024-01-12
# 304318    2024-01-29         2024-01-12
# 300673    2024-01-30         2024-01-12
# 297026    2024-01-31         2024-01-12
# 293373    2024-02-01         2024-01-12
# 289725    2024-02-02         2024-01-12
# 286076    2024-02-03         2024-01-12
# 282427    2024-02-04         2024-01-12
# 278776    2024-02-05         2024-01-12
# 275135    2024-02-06         2024-01-12
# 271489    2024-02-07         2024-01-12
# 267846    2024-02-08         2024-01-12
# 264191    2024-02-09         2024-01-12
# 260546    2024-02-10         2024-01-12
# 256900    2024-02-11         2024-01-12
# 253252    2024-02-12         2024-01-12
# 154685    2024-03-10         2024-03-08
# 151032    2024-03-11         2024-03-08
# 147391    2024-03-12         2024-03-08
# 143738    2024-03-13         2024-03-08
# 139976    2024-03-14         2024-03-08
# 136052    2024-03-16         2024-03-08
# 132214    2024-03-18         2024-03-08
# 128558    2024-03-19         2024-03-08
# 124910    2024-03-20         2024-03-08
# 121262    2024-03-21         2024-03-08
# 117612    2024-03-22         2024-03-08

# %% [markdown]
# This information confirms our believes. it looks like this song was re launched on 03/08 after their originall launch on 01/12. We can either correct the popularity column and the relase date or keep it as it is. for the time being we will keep the information as the same song releasing twice.
#
# Now lets look at the missing values for album_release_date, album_name, artist and name:

# %%
songs_name_missing = songs_data.loc[songs_data['name'].isna(), 'spotify_id'].unique()
songs_data[songs_data['spotify_id'].isin(songs_name_missing)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113 entries, 139937 to 680857
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   spotify_id          113 non-null    object
#  1   name                88 non-null     object
#  2   artists             88 non-null     object
#  3   daily_rank          113 non-null    int64
#  4   daily_movement      113 non-null    int64
#  5   weekly_movement     113 non-null    int64
#  6   country             113 non-null    object
#  7   snapshot_date       113 non-null    datetime64[ns]
#  8   popularity          113 non-null    int64
#  9   is_explicit         113 non-null    bool
#  10  duration_ms         113 non-null    int64
#  11  album_name          88 non-null     object
#  12  album_release_date  88 non-null     datetime64[ns]
#  13  danceability        113 non-null    float64
#  14  energy              113 non-null    float64
#  15  key                 113 non-null    int64
#  16  loudness            113 non-null    float64
#  17  mode                113 non-null    int64
#  18  speechiness         113 non-null    float64
#  19  acousticness        113 non-null    float64
#  20  instrumentalness    113 non-null    float64
#  21  liveness            113 non-null    float64
#  22  valence             113 non-null    float64
#  23  tempo               113 non-null    float64
#  24  time_signature      113 non-null    int64
#  25  top_5               113 non-null    bool
# dtypes: bool(2), datetime64[ns](2), float64(9), int64(8), object(5)
# memory usage: 22.3+ KB

# %%
for s in songs_name_missing:
    print('spotify_id: ' + s)
    print(len(songs_data.loc[songs_data['spotify_id'] == s, 'album_release_date'].unique()))
    print('\n')
# Out:
# spotify_id: 3vz3SKnCyJCzPuXWLoGfdG
# 1
#
#
# spotify_id: 2h4b8QdmU4nxZrlpz7INIs
# 1
#
#
# spotify_id: 2V2K1hzCtgj9xAnga9WUTy
# 2
#
#
# spotify_id: 7lyv2sysHCzFjypILxAynT
# 1
#
#
# spotify_id: 0kvD9ksvXyRHANPypIpkIh
# 1
#
#
# spotify_id: 6yxtsR3nc3aUL1wcbLn8A3
# 2

# %% [markdown]
# as we can see from the data, the data missing is name, artists, album_name and album_release_date. iterating through the missing data we identify that only 2 out of the 6 songs with missing data have this info on other records, in this case we will get rid of the rows with NA on these columns.

# %%
songs_data.shape
# Out:
# (683103, 26)

# %%
songs_data.dropna(subset = ['name', 'artists', 'album_name', 'album_release_date'], inplace = True)
songs_data.shape
# Out:
# (682853, 26)

# %%
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 682853 entries, 0 to 683102
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   spotify_id          682853 non-null  object
#  1   name                682853 non-null  object
#  2   artists             682853 non-null  object
#  3   daily_rank          682853 non-null  int64
#  4   daily_movement      682853 non-null  int64
#  5   weekly_movement     682853 non-null  int64
#  6   country             682853 non-null  object
#  7   snapshot_date       682853 non-null  datetime64[ns]
#  8   popularity          682853 non-null  int64
#  9   is_explicit         682853 non-null  bool
#  10  duration_ms         682853 non-null  int64
#  11  album_name          682853 non-null  object
#  12  album_release_date  682853 non-null  datetime64[ns]
#  13  danceability        682853 non-null  float64
#  14  energy              682853 non-null  float64
#  15  key                 682853 non-null  int64
#  16  loudness            682853 non-null  float64
#  17  mode                682853 non-null  int64
#  18  speechiness         682853 non-null  float64
#  19  acousticness        682853 non-null  float64
#  20  instrumentalness    682853 non-null  float64
#  21  liveness            682853 non-null  float64
#  22  valence             682853 non-null  float64
#  23  tempo               682853 non-null  float64
#  24  time_signature      682853 non-null  int64
#  25  top_5               682853 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float64(9), int64(8), object(5)
# memory usage: 131.5+ MB

# %% [markdown]
# Since the economic information has the countries names and the spotify data has 2 letter codes. We need to identify the codes with the countries. To do this we are pulling the list and standardizing:

# %%
country_codes = pd.read_csv('../raw_data/Country Data Codes.csv')

# %%
#lets only keep the column for the code information and re name the columns to standard names
country_codes = country_codes[['Name', 'ISO 3166']].rename(columns = {'Name' : 'name', 'ISO 3166' : 'code'})

# %%
country_codes.head()
# Out:
#              name        code
# 0     Afghanistan  AF|AFG|004
# 1        Akrotiri           -
# 2         Albania  AL|ALB|008
# 3         Algeria  DZ|DZA|012
# 4  American Samoa  AS|ASM|016

# %%
#clean up for missing values
country_codes.replace('-', np.nan, inplace = True)
country_codes.dropna(inplace=True)

# %%
#use the split text to identify the desired country code type
country_codes['code_standard'] = country_codes['code'].str.split('|', expand = True).loc[:,0]

# %%
country_codes['name'] = country_codes['name'].str.lower()

# %%
country_codes.drop(columns = ['code'], inplace = True)

# %%
country_codes.head()
# Out:
#              name code_standard
# 0     afghanistan            AF
# 2         albania            AL
# 3         algeria            DZ
# 4  american samoa            AS
# 5         andorra            AD

# %% [markdown]
# After the data cleaning, we have a list of country codes that map the name to the code seen int he original data. The next step is analysing the economic data. First we are going to analyse is the GDP. to do this we will import the first file first:

# %%
gdp_raw = pd.read_excel('../raw_data/RealPerCapitaGDPValues.xlsx', header = 12)

# %%
#filtering out for 2024 projection GDP only
gdp_data = gdp_raw.iloc[:,[0,55]]

# %%
gdp_data.head()
# Out:
#                     Country         y2024
# 0                     World  11836.473633
# 1            World less USA   9513.464844
# 2  United States and Canada  62066.617188
# 3                    Canada  46015.933594
# 4             United States  63912.871094

# %%
#cleaning up some values to align with the names in our country list
gdp_data = gdp_data.replace({'Czech Republic':'Czechia', 'Turkey' : 'Turkey (Turkiye)', 'Korea' : 'Korea, South'})

# %%
#lowercase the country name to be able to map 
gdp_data['Country'] = gdp_data['Country'].str.lower()
#merge on the country names
gdp_standard = pd.merge(gdp_data, country_codes, how = 'inner', left_on = 'Country', right_on = 'name').loc[:,['code_standard', 'y2024']]
#standardize column names
gdp_standard.rename(columns={'code_standard':'country', 'y2024' : 'GDP'}, inplace = True)

# %%
gdp_standard.head()
# Out:
#   country           GDP
# 0      CA  46015.933594
# 1      US  63912.871094
# 2      MX   9943.960938
# 3      AG  15941.398438
# 4      BB  16515.416016

# %%
gdp_standard.plot.hist()
plt.show()

# %% [markdown]
# It looks like the GDP distribution doesn't have odd values. Now that we have standardized the GDP data and reviewed the distribution, we can continue with the CPI (customer price index):

# %%
cpi_raw = pd.read_excel('../raw_data/CPIValues.xlsx', header = 11)

# %%
#only keeping the information for 2024
cpi_data = cpi_raw.iloc[:,[0,55]]

# %%
cpi_data.head()
# Out:
#                     Country       y2024
# 0                     World  195.991632
# 1            World less USA  216.508849
# 2  United States and Canada  131.874056
# 3                    Canada  126.241714
# 4             United States  132.357056

# %%
cpi_data = cpi_data.replace({'Czech Republic':'Czechia', 'Turkey' : 'Turkey (Turkiye)', 'Korea' : 'Korea, South'})

# %%
#lowercase the country name to be able to map 
cpi_data['Country'] = gdp_data['Country'].str.lower()
#merge on the country names
cpi_standard = pd.merge(cpi_data, country_codes, how = 'inner', left_on = 'Country', right_on = 'name').loc[:,['code_standard', 'y2024']]
#standardize column names
cpi_standard.rename(columns={'code_standard':'country', 'y2024' : 'CPI'}, inplace = True)

# %%
cpi_standard.head()
# Out:
#   country         CPI
# 0      CA  126.241714
# 1      US  132.357056
# 2      MX  153.578979
# 3      AG  123.362694
# 4      BB  143.994186

# %%
cpi_standard.plot.hist()
plt.show()

# %% [markdown]
# From the looks of it, it looks like the data is all over the place with most of the CPI being close to 0 and few values in the close to the hundreds of trillions. before we continue lets take a look:

# %%
cpi_standard.sort_values(by = 'CPI', ascending = False)
# Out:
#     country           CPI
# 31       VE  5.816421e+13
# 164      SD  8.861456e+04
# 168      ZW  6.738077e+04
# 118      LB  9.822397e+03
# 121      SY  5.405348e+03
# ..      ...           ...
# 17       PA  1.099166e+02
# 119      OM  1.094082e+02
# 80       JP  1.088154e+02
# 62       CH  1.079099e+02
# 151      ER  9.425235e+01
#
# [169 rows x 2 columns]

# %%
cpi_standard.describe()
# Out:
#                 CPI
# count  1.690000e+02
# mean   3.441669e+11
# std    4.474170e+12
# min    9.425235e+01
# 25%    1.233627e+02
# 50%    1.377599e+02
# 75%    1.716164e+02
# max    5.816421e+13

# %% [markdown]
# It looks like Venezuela has a very abnormal consumer price index. this makes sense as this country has been suffering extremely high inflation. For the CPI, the numbers are not as centered and close to 0 but the variabilty is explained so we will leave them (and not ignore them).

# %% [markdown]
# Now that we have the Economic indicators, we can join them to the original dataset:

# %%
songs_data = pd.merge(songs_data, gdp_standard, on = 'country', how = 'left')

# %%
songs_data = pd.merge(songs_data, cpi_standard, on = 'country', how = 'left')

# %%
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682853 entries, 0 to 682852
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   spotify_id          682853 non-null  object
#  1   name                682853 non-null  object
#  2   artists             682853 non-null  object
#  3   daily_rank          682853 non-null  int64
#  4   daily_movement      682853 non-null  int64
#  5   weekly_movement     682853 non-null  int64
#  6   country             682853 non-null  object
#  7   snapshot_date       682853 non-null  datetime64[ns]
#  8   popularity          682853 non-null  int64
#  9   is_explicit         682853 non-null  bool
#  10  duration_ms         682853 non-null  int64
#  11  album_name          682853 non-null  object
#  12  album_release_date  682853 non-null  datetime64[ns]
#  13  danceability        682853 non-null  float64
#  14  energy              682853 non-null  float64
#  15  key                 682853 non-null  int64
#  16  loudness            682853 non-null  float64
#  17  mode                682853 non-null  int64
#  18  speechiness         682853 non-null  float64
#  19  acousticness        682853 non-null  float64
#  20  instrumentalness    682853 non-null  float64
#  21  liveness            682853 non-null  float64
#  22  valence             682853 non-null  float64
#  23  tempo               682853 non-null  float64
#  24  time_signature      682853 non-null  int64
#  25  top_5               682853 non-null  bool
#  26  GDP                 673649 non-null  float64
#  27  CPI                 673649 non-null  float64
# dtypes: bool(2), datetime64[ns](2), float64(11), int64(8), object(5)
# memory usage: 136.8+ MB

# %%
songs_data.loc[songs_data['GDP'].isna(), 'country'].value_counts()
# Out:
# country
# Global    9204
# Name: count, dtype: int64

# %% [markdown]
# Now that all data has been cleaned up and combined (with only the global records missing economic information). We can save the data in our files

# %%
# save the data to a new csv file`
songs_data.to_csv('../data/songs_data_cleaned.csv')

# %% [markdown]
# Summary:
# The data wrangling process took several steps.<br>
# - First we analyzed the spotify data and found very little missing values. made sense of the missing countries (as global values). and identified that each record represents a songs position on a given country on a specific date. <br>
# - we also identified that there are some songs that have been "relaunched" a couple of times, we decided to keep the data as it is for now and see how each re launch impacts the chances of the song to making it to the top 5. <br>
# - we finally identified records with name, album_name missing values and most of these had no feasible way to re construct (except for 2 records). Decided to drop all values with missing information (due to the very little impact to the overall dataset).
# <br>
# - Analyzed the GDP data and found it to follow a distribution close to 0 with no abnromal values and the CPI which fiollows a more wide distribution with an outlayer for venezyuela that reflects the very high inflation. we decided to keep all records.
# <br>
# - Finally, we merged the economic indicators and the spotify data into a single dataset and saved it for further analysis.
